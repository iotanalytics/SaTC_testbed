# %%
import os
os.chdir('/content/drive/MyDrive/Case_Study_1_BearingFault_Data/Data_csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\steph\OneDrive\Documents\GitHub\SaTC_testbed\stepstone_attack\attack_detection\Online_SST_mod.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000000?line=0'>1</a> import os
# ----> <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000000?line=1'>2</a> os.chdir('/content/drive/MyDrive/Case_Study_1_BearingFault_Data/Data_csv')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/content/drive/MyDrive/Case_Study_1_BearingFault_Data/Data_csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
#from keras.models import load_model
from scipy.fftpack import fft

# %%
dataCollect.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\steph\OneDrive\Documents\GitHub\SaTC_testbed\stepstone_attack\attack_detection\Online_SST_mod.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000003?line=0'>1</a> dataCollect.shape
#
# NameError: name 'dataCollect' is not defined

# %% [markdown]
# ## This block is just reading data
# #### We will only use dataCollect afterwards. dataCollect.shape = (20000,9)
# #### 20000 is the length of time series, 9 is the number of features

# %%
directory = r'/content/drive/MyDrive/Case_Study_1_BearingFault_Data/Data_csv'
os.listdir(directory)
os.chdir('/content/drive/MyDrive/Case_Study_1_BearingFault_Data/Data_csv')
# f_s, Nn, num_time_periods, dataWindow =2000, 200, 20, 400 #parameter definition
# #featuredata = np.zeros((len(os.listdir(directory))*length_data),15*num_time_periods)
# #labeldata = np.zeros(((len(os.listdir(directory))*length_data),4)
time_len=20000
data_arrange=np.zeros((20000,10,9))
j=-1
for filename in os.listdir(directory):
  if(filename.endswith("csv")):
    j=j+1
    print(filename)
    dataCollectIni = read_csv(filename,header=None).iloc[::10,1:] #obtain the current waveform
    dataCollect = dataCollectIni.values
    dataCollect = dataCollect[:,[0,1,2,4,5,6,7,8,9]]
    dataCollect = dataCollect.astype(float)
    for i in range(9):
      data_arrange[:,j,i]=dataCollect[:,i]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\steph\OneDrive\Documents\GitHub\SaTC_testbed\stepstone_attack\attack_detection\Online_SST_mod.ipynb Cell 6' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000005?line=0'>1</a> directory = r'/content/drive/MyDrive/Case_Study_1_BearingFault_Data/Data_csv'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000005?line=1'>2</a> os.listdir(directory)
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000005?line=2'>3</a> os.chdir('/content/drive/MyDrive/Case_Study_1_BearingFault_Data/Data_csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000005?line=3'>4</a> # f_s, Nn, num_time_periods, dataWindow =2000, 200, 20, 400 #parameter definition
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000005?line=4'>5</a> # #featuredata = np.zeros((len(os.listdir(directory))*length_data),15*num_time_periods)
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000005?line=5'>6</a> # #labeldata = np.zeros(((len(os.listdir(directory))*length_data),4)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/content/drive/MyDrive/Case_Study_1_BearingFault_Data/Data_csv'

# %%
import os
os.chdir('/content/drive/MyDrive/singular-spectrum-transformation-master')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\steph\OneDrive\Documents\GitHub\SaTC_testbed\stepstone_attack\attack_detection\Online_SST_mod.ipynb Cell 7' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000006?line=0'>1</a> import os
# ----> <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000006?line=1'>2</a> os.chdir('/content/drive/MyDrive/singular-spectrum-transformation-master')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/content/drive/MyDrive/singular-spectrum-transformation-master'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import time, datetime
import pytz
import pandas as pd
import tensorflow

from tensorflow import keras
from pandas import read_csv
from influxdb import InfluxDBClient
from keras.models import load_model
from scipy.fftpack import fft
from numba import jit
from sklearn.preprocessing import MinMaxScaler
from fastsst.util.linear_algebra import power_method, lanczos, eig_tridiag
# Out:
# c:\Users\steph\OneDrive\Documents\GitHub\SaTC_testbed\stepstone_attack\attack_detection\fastsst\sst.py:199: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (array(float64, 2d, A), array(float64, 2d, A))
#   _, s, _ = np.linalg.svd(U_test[:, :n_components].T @
# C:\Users\steph\anaconda3\lib\site-packages\numba\core\typing\npydecl.py:965: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (array(float64, 2d, A), array(float64, 2d, A))
#   warnings.warn(NumbaPerformanceWarning(msg))

# %%
####### The input could only have the first decision score after the start data comes in

# %%
class SingularSpectrumTransformation():
    """SingularSpectrumTransformation class."""

    def __init__(self, win_length, x0, n_components=5, order=None, lag=None,
                 is_scaled=False, use_lanczos=True, rank_lanczos=None, eps=1e-3):
        """Change point detection with Singular Spectrum Transformation.
        Parameters
        ----------
        win_length : int
            window length of Hankel matrix.
        n_components : int
            specify how many rank of Hankel matrix will be taken.
        order : int
            number of columns of Hankel matrix.
        lag : int
            interval between history Hankel matrix and test Hankel matrix.
        is_scaled : bool
            if false, min-max scaling will be applied(recommended).
        use_lanczos : boolean
            if true, Lanczos method will be used, which makes faster.
        rank_lanczos : int
            the rank which will be used for lanczos method.
            for the detail of lanczos method, see [1].
        eps : float
            specify how much noise will be added to initial vector for
            power method.
            (FELIX: FEedback impLIcit kernel approXimation method)
            for the detail, see [2].
        References
        ----------
        [1]: Tsuyoshi Ide et al., Change-Point Detection using Krylov Subspace Learning
        [2]: Tsuyoshi Ide, Speeding up Change-Point Detection using Matrix Compression (Japanse)
        """
        self.win_length = win_length
        self.n_components = n_components
        self.order = order
        self.lag = lag
        self.is_scaled = is_scaled
        self.use_lanczos = use_lanczos
        self.rank_lanczos = rank_lanczos
        self.eps = eps

    def score_online(self, x):
        """Calculate anomaly score (offline).
        Parameters
        ----------
        x : 1d numpy array
            input time series data.
        Returns
        -------
        score : 1d array
            change point score.
        """
        if self.order is None:
            # rule of thumb
            self.order = self.win_length
        if self.lag is None:
            # rule of thumb
            self.lag = self.order // 2
        if self.rank_lanczos is None:
            # rule of thumb
            if self.n_components % 2 == 0:
                self.rank_lanczos = 2 * self.n_components
            else:
                self.rank_lanczos = 2 * self.n_components - 1

        assert isinstance(x, np.ndarray), "input array must be numpy array."
        assert x.ndim == 1, "input array dimension must be 1."
        assert isinstance(self.win_length, int), "window length must be int."
        assert isinstance(self.n_components, int), "number of components must be int."
        assert isinstance(self.order, int), "order of partial time series must be int."
        assert isinstance(self.lag, int), "lag between test series and history series must be int."
        assert isinstance(self.rank_lanczos, int), "rank for lanczos must be int."
        # assert self.win_length + self.order + self.lag < x.size, "data length is too short."

        # all values should be positive for numerical stabilization
        # if not self.is_scaled:
        #     x_scaled = MinMaxScaler(feature_range=(1, 2))\
        #         .fit_transform(x.reshape(-1, 1))[:, 0]
        # else:
        x_hist = x[:self.win_length+self.lag]
        x_new = x[self.lag:]
        score, x1 = _score_online(x_hist, x_new, x0, self.order,
            self.win_length, self.lag, self.n_components, self.rank_lanczos,
            self.eps, use_lanczos=self.use_lanczos)

        return score, x1

@jit(nopython=True)
def _score_online(x, y, x0, order, win_length, lag, n_components, rank, eps, use_lanczos):
    """Core implementation of offline score calculation."""
    # start_idx = win_length + order + lag + 1
    # end_idx = x.size + 1



    score = np.zeros(1)
    # for t in range(start_idx, end_idx):
    # compute score at each index

    # get Hankel matrix
    X_history = _create_hankel(x, order,
        start=order,
        end=win_length-lag)
    X_test = _create_hankel(y, order,
        start=order,
        end=win_length-lag)

    if use_lanczos:
        score, x1 = _sst_lanczos(X_test, X_history, n_components,
                                      rank, x0)
        # update initial vector for power method
        x0 = x1 + eps * np.random.rand(x0.size)
        x0 /= np.linalg.norm(x0)
    else:
        score = _sst_svd(X_test, X_history, n_components)

    return score,x0


@jit(nopython=True)
def _create_hankel(x, order, start, end):
    """Create Hankel matrix.
    Parameters
    ----------
    x : full time series
    order : order of Hankel matrix
    start : start index
    end : end index
    Returns
    -------
    2d array shape (window length, order)
    """
    win_length = end - start
    X = np.empty((win_length, order))
    for i in range(order):
        X[:, i] = x[(start - i):(end - i)]
    return X


@jit(nopython=True)
def _sst_lanczos(X_test, X_history, n_components, rank, x0):
    """Run sst algorithm with lanczos method (FELIX-SST algorithm)."""
    P_history = X_history.T @ X_history
    P_test = X_test.T @ X_test
    # calculate the first singular vec of test matrix
    u, _, _ = power_method(P_test, x0, n_iter=1)
    T = lanczos(P_history, u, rank)
    vec, val = eig_tridiag(T)
    return 1 - (vec[0, :n_components] ** 2).sum(), u


@jit("f8(f8[:,:],f8[:,:],u1)", nopython=True)
def _sst_svd(X_test, X_history, n_components):
    """Run sst algorithm with svd."""
    U_test, _, _ = np.linalg.svd(X_test, full_matrices=False)
    U_history, _, _ = np.linalg.svd(X_history, full_matrices=False)
    _, s, _ = np.linalg.svd(U_test[:, :n_components].T @
        U_history[:, :n_components], full_matrices=False)
    return 1 - s[0]
# Out:
# C:\Users\steph\AppData\Local\Temp\ipykernel_24320\3783873901.py:158: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (array(float64, 2d, A), array(float64, 2d, A))
#   _, s, _ = np.linalg.svd(U_test[:, :n_components].T @
# C:\Users\steph\anaconda3\lib\site-packages\numba\core\typing\npydecl.py:965: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (array(float64, 2d, A), array(float64, 2d, A))
#   warnings.warn(NumbaPerformanceWarning(msg))

# %%
username = "test"
pwd = "sensorweb"
#pwd = "sensorweb128"

#client = InfluxDBClient(host = 'sensorwebturing.engr.uga.edu', port = 8086, ssl=True)
#client.switch_database("satcdb")
client = InfluxDBClient(host = 'sensorweb.us', port = 8086, username=username, password=pwd, ssl=True)
client.switch_database("testdb")

currentTime = datetime.datetime.now()
timestamp = int(currentTime.timestamp()*1000000000)
print(timestamp)
timestamp = 1644466568662305024
# Out:
# 1654113162965558016

# %%
order=50
win_length=100
lag=50
pre_len = order + win_length + lag
# pre_len = 3

# get first data window
query = f'SELECT "sensor1_AC_mag" FROM "NI_Waveform" WHERE  time <= {timestamp} LIMIT {pre_len}'
#query = f'SELECT "sensor1_DC_freq" FROM "satcdb" WHERE "time" < {timestamp}'
#query = f'SELECT "sensor1_AC_mag" FROM "NI_Waveform" WHERE location = ''[\'sensorweb128\']'' AND time <= {timestamp} LIMIT {pre_len}'
print(query)

result = client.query(query)

values = result.get_points()

## Format for influxdb timestamps: "%Y-%m-%dT%H:%M:%S.%fZ"

start_window = np.empty(pre_len)
for point in values:
    timeString = point['time']
    np.append(start_window, point['sensor1_AC_mag'])
    #np.append(start_window, point['sensor1_DC_freq'])
    element = datetime.datetime.strptime(timeString,"%Y-%m-%dT%H:%M:%S.%fZ")  
    endTime = int(datetime.datetime.timestamp(element)*1000000000)
    print(endTime)
    #print(timeString)

# start=dataCollect[:pre_len,:]
start=start_window
print("start shape is",start.shape)
print("start type is ",type(start))
smean = np.mean(start)
# Out:
# SELECT "sensor1_AC_mag" FROM "NI_Waveform" WHERE  time <= 1644466568662305024 LIMIT 200
# 1644484561117417216
# 1644484561870845952
# 1644484562616873984
# 1644484563368087040
# 1644484564118617088
# 1644484564881440000
# 1644484565627931136
# 1644484566390671104
# 1644484567148948992
# 1644484567911955968
# 1644484568662305024
# start shape is (200,)
# start type is  <class 'numpy.ndarray'>
# C:\Users\steph\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sensorweb.us'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
Score_start=np.zeros(1) # get the initial score, Score_start
x0 = np.empty(order, dtype=np.float64) 
x0 = np.random.rand(order)
x0 /= np.linalg.norm(x0)
print(x0.shape)

x = start
score_start, x0 = SingularSpectrumTransformation(win_length=win_length, x0=x0, n_components=2,order=order, lag=order,is_scaled=True).score_online(start)
Score_start=score_start+Score_start
# Out:
# (50,)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# c:\Users\steph\OneDrive\Documents\GitHub\SaTC_testbed\stepstone_attack\attack_detection\Online_SST_mod.ipynb Cell 13' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000012?line=4'>5</a> print(x0.shape)
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000012?line=6'>7</a> x = start
# ----> <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000012?line=7'>8</a> score_start, x0 = SingularSpectrumTransformation(win_length=win_length, x0=x0, n_components=2,order=order, lag=order,is_scaled=True).score_online(start)
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000012?line=8'>9</a> Score_start=score_start+Score_start
#
# c:\Users\steph\OneDrive\Documents\GitHub\SaTC_testbed\stepstone_attack\attack_detection\Online_SST_mod.ipynb Cell 10' in SingularSpectrumTransformation.score_online(self, x)
#      <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000009?line=80'>81</a> x_hist = x[:self.win_length+self.lag]
#      <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000009?line=81'>82</a> x_new = x[self.lag:]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000009?line=82'>83</a> score, x1 = _score_online(x_hist, x_new, x0, self.order,
#      <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000009?line=83'>84</a>     self.win_length, self.lag, self.n_components, self.rank_lanczos,
#      <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000009?line=84'>85</a>     self.eps, use_lanczos=self.use_lanczos)
#      <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000009?line=86'>87</a> return score, x1
#
# File ~\anaconda3\lib\site-packages\numba\np\linalg.py:751, in _check_finite_matrix()
#     <a href='file:///c%3A/Users/steph/anaconda3/lib/site-packages/numba/np/linalg.py?line=748'>749</a> for v in np.nditer(a):
#     <a href='file:///c%3A/Users/steph/anaconda3/lib/site-packages/numba/np/linalg.py?line=749'>750</a>     if not np.isfinite(v.item()):
# --> <a href='file:///c%3A/Users/steph/anaconda3/lib/site-packages/numba/np/linalg.py?line=750'>751</a>         raise np.linalg.LinAlgError(
#     <a href='file:///c%3A/Users/steph/anaconda3/lib/site-packages/numba/np/linalg.py?line=751'>752</a>             "Array must not contain infs or NaNs.")
#
# LinAlgError: Array must not contain infs or NaNs.

# %% [markdown]
# ### Below we use one exmaple, that only calculates one dimension of time series' anomaly score.

# %%
from scipy.fftpack.basic import ifft
import matplotlib.pyplot as plt

windowSize=15000  #### here we assume the dataCollect is coming into the algorithm sequentially, the total length of time series is WindowSize
stream=dataCollect[pre_len:windowSize,3]  #### the total data we would import in the streaming algorithm, "3" is just one diemnsion of the data
#### pre_len:windowSize is the length of time series we used in streaming algorithm

nwin=147  ### we assume there is 147 windows, if given the data above.
lastdata=start[:,3]  ### the initial start of the algorithm

Score=np.zeros(nwin) 
# var_score=np.zeros(nwin)

thres1=0.2 #(normally, thres2 < thres1)
thres2=0.1
state=0
move=100
# thres=max(var_score[:4000])
import time
for j in range(nwin):
  # print(j)
  starttime=time.time()
  data=np.concatenate((lastdata[lag:], stream[lag*j:lag*(j+1)]), axis=None) #### concatenate the data from last window and the incoming data window
  # print(data.shape)
  score, x0 = SingularSpectrumTransformation(win_length=win_length, x0=x0, n_components=2,order=order, lag=order,is_scaled=True).score_online(data)
  Score[j]=score*10**4
  lastdata=data  ##### assign the current data as the lastdata window, ready for the incoming data
  # var_score[j]=50*np.var(Score[(j-move):j])
  if Score[j] > thres1 and state==0:   
    print("At time" , j , ", the anomaly starts") 
    state=1 
  elif Score[j] < thres2 and state==1:  
    print("At time" , j , ", the anomaly ends")
    state=0
  else:
    pass
  end=time.time()
  duration=end-starttime
  print(f"Runtime of one data window is {duration}")
plt.plot(Score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\steph\OneDrive\Documents\GitHub\SaTC_testbed\stepstone_attack\attack_detection\Online_SST_mod.ipynb Cell 15' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000014?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000014?line=3'>4</a> windowSize=15000  #### here we assume the dataCollect is coming into the algorithm sequentially, the total length of time series is WindowSize
# ----> <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000014?line=4'>5</a> stream=dataCollect[pre_len:windowSize,3]  #### the total data we would import in the streaming algorithm, "3" is just one diemnsion of the data
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000014?line=5'>6</a> #### pre_len:windowSize is the length of time series we used in streaming algorithm
#       <a href='vscode-notebook-cell:/c%3A/Users/steph/OneDrive/Documents/GitHub/SaTC_testbed/stepstone_attack/attack_detection/Online_SST_mod.ipynb#ch0000014?line=7'>8</a> nwin=147  ### we assume there is 147 windows, if given the data above.
#
# NameError: name 'dataCollect' is not defined
